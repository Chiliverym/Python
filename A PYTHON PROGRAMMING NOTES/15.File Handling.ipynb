# %%
file= open("sample.txt","r")
content = file.read()
print(content)
file.close()
# Out:
# test run check 2

# %%
# C:\Users\hp\Music

# %%
way 1 : C:\\Users\\hp\\Music\\newdocument.txt

# %%
file= open("C:\\Users\\hp\\Music\\newdocument.txt","r")
content = file.read()
print(content)
file.close()
# Out:
# this is first line
# this is second line
# this is third line
# this is fourth line

# %% [raw]
# way 2 : C:/Users/hp/Music/newdocument.txt

# %%
file= open("C:/Users/hp/Music/newdocument.txt","r")
content = file.read()
print(content)
file.close()
# Out:
# this is first line
# this is second line
# this is third line
# this is fourth line

# %%
#code to copy data from one file to another file

f1 = open("C:/Users/hp/Music/newdocument.txt",'r')
f2 = open("copydoc.txt",'w')

for data in f1:
    f2.write(data)
    print(data)
    
f1.close()
f2.close()
# Out:
# this is first line
#
# this is second line
#
# this is third line
#
# this is fourth line

# %% [raw]
# To read the images in binary

# %%
file = open("pythonlogo.jpg","rb")
content = file.read()
print(content)
file.close()
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00\x84\x00\t\x06\x07\x0e\x13\x0e\x0e\x0e\x0e\x11\x11\x0e\x10\x11\x11\x11\x11\x0e\x0e\x10\x11\x11\x11\x0f\x0e\x0e\x18\x12\x17\x17\x17\x14\x16\x14\x19\x1e*!\x1a\x1b&\x1e\x16\x16"?$&+-110\x18 5:5/:*/0-\x01\n\n\n\x0f\x0e\x0f\x1c\x11\x11\x1c2#\x1e#-//////--/-2-///2---/1/-//////--2//---//1//-/-/-/-\xff\xc0\x00\x11\x08\x00\xe1\x00\xe1\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1c\x00\x01\x00\x02\x03\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x01\x06\x04\x05\x07\x02\x03\x08\xff\xc4\x00G\x10\x00\x02\x01\x01\x03\x04\x0b\x0c\x08\x06\x03\x01\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x11\x12!1Q\x06\x07"ARaq\x91\x93\xa1\xd1\x13\x14\x15\x1723Srs\x81\x92\xb1\x164\xa2\xb2\xb3\xc1\xd3\xe1#5B\x82\xd2\xf0$bt\xc2\xff\xc4\x00\x1b\x01\x00\x02\x03\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x01\x03\x04\x05\x02\x06\x07\xff\xc4\x009\x11\x00\x02\x01\x01\x03\t\x05\x06\x05\x05\x01\x00\x00\x00\x00\x00\x00\x01
# ...

# %%
f1 = open("pythonlogo.jpg","rb")
f2 = open("logocopy.jpg","wb")

for data in f1:
    f2.write(data)
    print(data)
    
f1.close()
f2.close()
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00\x84\x00\t\x06\x07\x0e\x13\x0e\x0e\x0e\x0e\x11\x11\x0e\x10\x11\x11\x11\x11\x0e\x0e\x10\x11\x11\x11\x0f\x0e\x0e\x18\x12\x17\x17\x17\x14\x16\x14\x19\x1e*!\x1a\x1b&\x1e\x16\x16"?$&+-110\x18 5:5/:*/0-\x01\n'
# b'\n'
# b'\n'
# ...

# %%
import os

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '1.Introduction to Python.ipynb',
#  '10. Operations on Sets .ipynb',
#  '11. Functions.ipynb',
#  '12. Anonymous Function.ipynb',
#  '13. Modules.ipynb',
#  '14. File Handling.ipynb',
#  '2.Variables, Data Types and Data Structures.ipynb',
#  '3.Operators.ipynb',
#  '4.Conditionals.ipynb',
#  '5.Loops.ipynb',
#  '6.Operations on Data Types.ipynb',
#  '7.Operations on List.ipynb',
#  '8.Operations on Tuples.ipynb',
#  '9. Operations on Dictionary.ipynb',
#  'copydoc.txt',
#  'database.txt',
#  'Flask.ipynb',
#  'logocopy.jpg',
#  'newfile.txt',
#  'pattern programming.ipynb',
#  'pythonlogo.jpg',
#  'sample.txt',
#  'testmodule.py',
#  'Untitled.ipynb',
#  '__pycache__']

# %%
os.remove('newfile.txt')

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '1.Introduction to Python.ipynb',
#  '10. Operations on Sets .ipynb',
#  '11. Functions.ipynb',
#  '12. Anonymous Function.ipynb',
#  '13. Modules.ipynb',
#  '14. File Handling.ipynb',
#  '2.Variables, Data Types and Data Structures.ipynb',
#  '3.Operators.ipynb',
#  '4.Conditionals.ipynb',
#  '5.Loops.ipynb',
#  '6.Operations on Data Types.ipynb',
#  '7.Operations on List.ipynb',
#  '8.Operations on Tuples.ipynb',
#  '9. Operations on Dictionary.ipynb',
#  'copydoc.txt',
#  'database.txt',
#  'Flask.ipynb',
#  'logocopy.jpg',
#  'pattern programming.ipynb',
#  'pythonlogo.jpg',
#  'sample.txt',
#  'testmodule.py',
#  'Untitled.ipynb',
#  '__pycache__']

# %%
from os import mkdir,listdir,remove,rmdir

# %%
while True:
    choice=int(input("\n1: create a dir\n2: Print a dir\n3: Remove a file/directory\n4:Exit "))
    
    if choice==1:
        folder = input("Enter the dir name: ")
        mkdir(folder)
        print("Directory created"+folder)
        
    if choice==2:
        folder=input("Enter the directory to browser : ")
        contents=listdir(folder)
        
        for f in contents:
            print(f)
            
    if choice==3:
        folder=input("Enter the directory to remove")
        rmdir(folder)
# Out:
# 1: create a dir
# 2: Print a dir
# 3: Remove a file/directory
# 4:Exit 4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [10], in <cell line: 2>()
#       1 while True:
# ----> 2     choice=int(input("\n1: create a dir\n2: Print a dir\n3: Remove a file/directory\n4:Exit "))
#       4     if choice==1:
#       5         folder = input("Enter the dir name: ")
#
# File ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py:1075, in Kernel.raw_input(self, prompt)
#    1071 if not self._allow_stdin:
#    1072     raise StdinNotImplementedError(
#    1073         "raw_input was called, but this frontend does not support input requests."
#    1074     )
# -> 1075 return self._input_request(
#    1076     str(prompt),
#    1077     self._parent_ident["shell"],
#    1078     self.get_parent("shell"),
#    1079     password=False,
#    1080 )
#
# ...

# %%
file = open("sample.txt","r")

# %%
file.readline()  #reading first line
# Out:
# 'test run check 2'

# %%
file.readline() #reading next line
# Out:
# ''

# %%
file.readline()  #reading next line
# Out:
# ''

# %%
file.readlines() #it is returning me the list of all the lines
# Out:
# []

# %%
file.close()

# %%
file = open("database.txt","r")
x = file.readlines()
x
# Out:
# ['\n',
#  'First name : Jayesh\n',
#  'Last name : Patil\n',
#  'Location : Kalyan\n',
#  'Age : 25\n',
#  'Salary : 25\n',
#  'Contact number : 123456\n',
#  '\n',
#  '\n',
#  '\n',
#  '        First name : Jayesh\n',
#  '        Last name : Patil\n',
#  '        Location : Kalyan\n',
#  '        Age : 25\n',
#  '        Salary : 24\n',
#  '        Contact number : 123456\n',
#  '\n',
#  '\n']

# %%
for i in x:
    print(i)
# Out:
# First name : Jayesh
#
# Last name : Patil
#
# Location : Kalyan
#
# Age : 25
#
# Salary : 25
#
# Contact number : 123456
#
#
#
#
#
#
#
#         First name : Jayesh
#
#         Last name : Patil
#
#         Location : Kalyan
#
#         Age : 25
#
#         Salary : 24
#
#         Contact number : 123456

# %%
import pickle

# %%
l1 = [1,2,3,4,5,6,7,8,"abc12"]
f=open("abc.txt",'wb')
pickle.dump(l1,f)
f.close()

# %%
f=open("abc.txt",'rb')
print(pickle.load(f))
f.close()
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 'abc12']
